# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

import kagglehub

# Download latest version
path = r"C:\Users\Mikey\Desktop\CHE891_Classwork\Process_Design\Class_Jupyter_Files\TEP_Faulty_Training.csv"

print("Path to dataset files:", path)



df = pd.read_csv(path)

# Drop non-numeric columns if present
df_numeric = df.select_dtypes(include=[np.number])

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_numeric)

# Reduce dimensionality for visualization
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Cluster the data
kmeans = KMeans(n_clusters=4, random_state=42)
labels = kmeans.fit_predict(X_pca)

# Visualize clusters
plt.figure(figsize=(8,6))
plt.scatter(X_pca[:,0], X_pca[:,1], c=labels, cmap='viridis', alpha=0.5)
plt.title('KMeans Clustering on PCA-reduced Fault Data')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.show()

# Print cluster sizes
print("Cluster sizes:", np.bincount(labels))
# Out:
# Path to dataset files: C:\Users\Mikey\Desktop\CHE891_Classwork\Process_Design\Class_Jupyter_Files\TEP_Faulty_Training.csv
# Cluster sizes: [ 209192 4305013   99297  386498]

# %% [markdown]
# I think I can identify two main clusters, presumably corresponding to two main faults, but I am not that familiar with this dataset.
