# %% [markdown]
# The softplus transformation helps promote physically meaningful positive predictions since impurity concentration cannot be under 0. When there are sharp negative spikes, softplus approaches zero smoothly without creating a sharp point. For both LARS and PLS, using softplus predicts the objective in a different target space than the strict impurity concentration, which can help with extreme outliers but does not necessarily guarantee an improved accuracy in the original space.
